# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
import glob
import os
from mpl_toolkits.mplot3d.axes3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable

#sort for latest file
list_of_files = glob.glob('*.csv') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx() 
plt.suptitle(latest_file, fontsize=16)
plt.ion()
fig.show()
fig.canvas.draw()

while True:

#     data=pd.read_csv(latest_file,skiprows=1,usecols=[0,1,2,3,4],header=None, names=['t','dac1','dac2','adc1','adc2'])
    data=pd.read_csv(latest_file,comment='#')

    data1=data
    data1=data1.astype(int)
    trw = data1.shape[0]
    data2=data1.iloc[trw-100:trw,:]
  
    ax1.clear()
    ax2.clear()
    ax1.set_ylabel('adc (V)')
    ax1.set_xlabel('Time (s)')
    s1=ax1.plot(data2.timestamp/1000,data2.adc1,'xkcd:lightblue',label = 'adc1')
    s2=ax1.plot(data2.timestamp/1000,data2.adc2,'xkcd:orange',label = 'adc2')
    ax1.minorticks_on()
    ax1.grid(which='major', linestyle='-', linewidth='0.5', color='black')
    ax1.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
      

    ax2.set_ylabel('dac (V)', color='blue')
    d1=ax2.plot(data2.timestamp/1000,data2.dac1,'xkcd:red',label = 'dac1')
    d2=ax2.plot(data2.timestamp/1000,data2.dac2,color=(0,0.1,0.8),label = 'dac2')
    ax2.tick_params(axis='y', labelcolor='blue')
    lns = s1+s2+d1+d2
    labs = [l.get_label() for l in lns]
    ax2.legend(lns, labs, loc='upper right', ncol=4)
    fig.tight_layout()
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
display(data1)
# Out:
#              t     dac1     dac2    adc1    adc2
# 0        151.0 -20000.0 -19000.0  1120.0  1967.0
# 1        279.0 -20000.0 -18000.0  1113.0  1965.0
# 2        407.0 -20000.0 -17000.0  1099.0  1967.0
# 3        535.0 -20000.0 -16000.0  1125.0  1964.0
# 4        664.0 -20000.0 -15000.0  1096.0  1959.0
# 5        792.0 -20000.0 -14000.0  1204.0  1904.0
# 6        919.0 -20000.0 -13000.0  1254.0  1818.0
# 7       1047.0 -20000.0 -12000.0  1200.0  1878.0
# 8       1176.0 -20000.0 -11000.0  1132.0  1966.0
# 9       1304.0 -20000.0 -10000.0  1114.0  1962.0
# 10      1432.0 -20000.0  -9000.0  1106.0  1961.0
# 11      1560.0 -20000.0  -8000.0  1177.0  1905.0
# 12      1688.0 -20000.0  -7000.0  1091.0  1963.0
# 13      1816.0 -20000.0  -6000.0  1250.0  1766.0
# 14      1944.0 -20000.0  -5000.0  1112.0  1957.0
# 15      2072.0 -20000.0  -4000.0  1197.0  1910.0
# 16      2200.0 -20000.0  -3000.0  1132.0  1968.0
# 17      2328.0 -20000.0  -2000.0  1201.0  1663.0
# ...

# %%
data2=data1
fig = plt.figure(figsize=plt.figaspect(0.5))

ax1 = fig.add_subplot(2, 2, 1, projection='3d')
ax1.set_title('QPD(B_T)')
p2=ax1.scatter(data2.dac1, data2.dac2, data2.adc1,c=data2.adc1*3.3, cmap='viridis', linewidth=0.01)
ax1.set_zlabel('ADC2 (V)')
ax1.set_xlabel('DAC1 (V)')
ax1.set_ylabel('DAC2 (V)')
ax1.azim = 45
ax1.elev = 20
fig.colorbar(p2,fraction=0.03, pad=0.04)

ax1 = fig.add_subplot(2, 2, 2, projection='3d')
ax1.set_title('QPD(L_R)')
p2=ax1.scatter(data2.dac1, data2.dac2, data2.adc2,c=data2.adc2*3.3, cmap='viridis', linewidth=0.01)
ax1.set_zlabel('ADC2 (V)')
ax1.set_xlabel('DAC1 (V)')
ax1.set_ylabel('DAC2 (V)')
ax1.azim = 45
ax1.elev = 70
fig.colorbar(p2,fraction=0.03, pad=0.04)

ax1 = fig.add_subplot(2, 2, 3, projection='3d')
ax1.set_title('QPD(B_T)')
p2=ax1.scatter(data2.dac1, data2.dac2, data2.adc1,c=data2.adc1*3.3, cmap='viridis', linewidth=0.01)
#ax1.set_zlabel('ADC2 (V)')
ax1.set_xlabel('DAC1 (V)')
ax1.set_ylabel('DAC2 (V)')
ax1.azim = 0
ax1.elev = 0
fig.colorbar(p2,fraction=0.03, pad=0.04)

ax1 = fig.add_subplot(2, 2, 4, projection='3d')
ax1.set_title('QPD(L_R)')
p2=ax1.scatter(data2.dac1, data2.dac2, data2.adc2,c=data2.adc2*3.3, cmap='viridis', linewidth=0.01)
#ax1.set_zlabel('ADC2 (V)')
ax1.set_xlabel('DAC1 (V)')
ax1.set_ylabel('DAC2 (V)')
ax1.azim = 90
ax1.elev = 0
fig.colorbar(p2,fraction=0.03, pad=0.04)
# Out:
# <img src="data:image/png;base64,..." width="960">
